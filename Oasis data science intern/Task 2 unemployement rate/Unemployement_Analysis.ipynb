# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Unemployment.csv')

# %%
#EDA

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline


sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (15, 15)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df.tail()
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 763    NaN   NaN        NaN                               NaN
# 764    NaN   NaN        NaN                               NaN
# 765    NaN   NaN        NaN                               NaN
# 766    NaN   NaN        NaN                               NaN
# 767    NaN   NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Area
# 763                  NaN                                       NaN  NaN
# 764                  NaN                                       NaN  NaN
# 765                  NaN                                       NaN  NaN
# 766                  NaN                                       NaN  NaN
# 767                  NaN                                       NaN  NaN

# %%
df.fillna(0,inplace=True)

# %%
df[' Date'] =pd.to_datetime(df[' Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    768 non-null    object
#  1    Date                                     768 non-null    datetime64[ns]
#  2    Frequency                                768 non-null    object
#  3    Estimated Unemployment Rate (%)          768 non-null    float64
#  4    Estimated Employed                       768 non-null    float64
#  5    Estimated Labour Participation Rate (%)  768 non-null    float64
#  6   Area                                      768 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 42.1+ KB

# %%
print(df.isna().sum())
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#              Region       Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31    Monthly                              3.65
# 1    Andhra Pradesh 2019-06-30    Monthly                              3.05
# 2    Andhra Pradesh 2019-07-31    Monthly                              3.75
# 3    Andhra Pradesh 2019-08-31    Monthly                              3.32
# 4    Andhra Pradesh 2019-09-30    Monthly                              5.17
# ..              ...        ...        ...                               ...
# 763               0 1970-01-01          0                              0.00
# 764               0 1970-01-01          0                              0.00
# 765               0 1970-01-01          0                              0.00
# 766               0 1970-01-01          0                              0.00
# 767               0 1970-01-01          0                              0.00
#
# ...

# %%
print(list(df))
# Out:
# ['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)', ' Estimated Employed', ' Estimated Labour Participation Rate (%)', 'Area']

# %%
region_df= df.groupby(by='Region').mean().sort_values(by=' Estimated Unemployment Rate (%)',ascending=False)
# Out:
# /tmp/ipykernel_103/2082764546.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   region_df= df.groupby(by='Region').mean().sort_values(by=' Estimated Unemployment Rate (%)',ascending=False)

# %%
region_df
# Out:
#                    Estimated Unemployment Rate (%)   Estimated Employed  \
# Region
# Tripura                                  28.350357         7.170026e+05
# Haryana                                  26.283214         3.557072e+06
# Jharkhand                                20.585000         4.469240e+06
# Bihar                                    18.918214         1.236619e+07
# Himachal Pradesh                         18.540357         1.059824e+06
# Delhi                                    16.495357         2.627513e+06
# Jammu & Kashmir                          16.188571         1.799932e+06
# Chandigarh                               15.991667         3.168312e+05
# Rajasthan                                14.058214         1.004106e+07
# Uttar Pradesh                            12.551429         2.809483e+07
# Punjab                                   12.031071         4.539362e+06
# Puducherry                               10.215000         2.122781e+05
# ...

# %%
#Which state is having highest Unemployement rate

# %%
region_df.sort_values(by=' Estimated Unemployment Rate (%)',ascending=False)
# Out:
#                    Estimated Unemployment Rate (%)   Estimated Employed  \
# Region
# Tripura                                  28.350357         7.170026e+05
# Haryana                                  26.283214         3.557072e+06
# Jharkhand                                20.585000         4.469240e+06
# Bihar                                    18.918214         1.236619e+07
# Himachal Pradesh                         18.540357         1.059824e+06
# Delhi                                    16.495357         2.627513e+06
# Jammu & Kashmir                          16.188571         1.799932e+06
# Chandigarh                               15.991667         3.168312e+05
# Rajasthan                                14.058214         1.004106e+07
# Uttar Pradesh                            12.551429         2.809483e+07
# Punjab                                   12.031071         4.539362e+06
# Puducherry                               10.215000         2.122781e+05
# ...

# %%
#get unemployement rate of Andhra Pradesh State

# %%
ap_unemployement_state_df= df[df.Region=='Andhra Pradesh']

# %%
ap_unemployement_state_df
# Out:
#              Region       Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31    Monthly                              3.65
# 1    Andhra Pradesh 2019-06-30    Monthly                              3.05
# 2    Andhra Pradesh 2019-07-31    Monthly                              3.75
# 3    Andhra Pradesh 2019-08-31    Monthly                              3.32
# 4    Andhra Pradesh 2019-09-30    Monthly                              5.17
# 5    Andhra Pradesh 2019-10-31    Monthly                              3.52
# 6    Andhra Pradesh 2019-11-30    Monthly                              4.12
# 7    Andhra Pradesh 2019-12-31    Monthly                              4.38
# 8    Andhra Pradesh 2020-01-31    Monthly                              4.84
# 9    Andhra Pradesh 2020-02-29    Monthly                              5.91
# 10   Andhra Pradesh 2020-03-31    Monthly                              4.06
# ...

# %%
ap_unemployement_state_df[' Estimated Unemployment Rate (%)'].mean()
# Out:
# 7.477142857142857

# %%
ap=ap_unemployement_state_df.loc[ap_unemployement_state_df[' Date'].dt.year == 2020]

# %%
ap[' Estimated Unemployment Rate (%)'].mean()
# Out:
# 11.010833333333332

# %%
#get the month in a year which is having highest unemployement rate

# %%
ap.sort_values(by=' Estimated Unemployment Rate (%)',ascending=False).head(1)
# Out:
#              Region       Date  Frequency   Estimated Unemployment Rate (%)  \
# 384  Andhra Pradesh 2020-04-30    Monthly                              32.3
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 384            2544084.0                                     26.97  Urban

# %%
region_df.reset_index(inplace = True)
states=list(region_df['Region'])
states.pop()
print(len(states))
states
# Out:
# 28
# ['Tripura',
#  'Haryana',
#  'Jharkhand',
#  'Bihar',
#  'Himachal Pradesh',
#  'Delhi',
#  'Jammu & Kashmir',
#  'Chandigarh',
#  'Rajasthan',
#  'Uttar Pradesh',
#  'Punjab',
#  'Puducherry',
#  'Kerala',
#  'Tamil Nadu',
#  'Goa',
#  'Chhattisgarh',
#  'West Bengal',
#  'Telangana',
#  'Maharashtra',
#  'Andhra Pradesh',
#  'Madhya Pradesh',
#  'Sikkim',
#  'Karnataka',
#  'Gujarat',
#  'Uttarakhand',
#  'Assam',
#  'Odisha',
#  'Meghalaya']

# %%
unemployement_rate= list(region_df[' Estimated Unemployment Rate (%)'])
unemployement_rate.pop()
unemployement_rate
# Out:
# [28.350357142857142,
#  26.283214285714283,
#  20.585,
#  18.91821428571429,
#  18.540357142857143,
#  16.49535714285714,
#  16.18857142857143,
#  15.991666666666667,
#  14.058214285714286,
#  12.551428571428572,
#  12.031071428571428,
#  10.215000000000002,
#  10.12392857142857,
#  9.284285714285714,
#  9.274166666666666,
#  9.240357142857144,
#  8.124642857142858,
#  7.737857142857143,
#  7.5575,
#  7.477142857142857,
#  7.406428571428571,
#  7.249411764705882,
#  6.676071428571428,
#  6.663928571428571,
#  6.582962962962963,
#  6.428076923076923,
#  5.657857142857142,
#  4.7988888888888885]

# %%
matplotlib.rcParams['figure.figsize'] = (20,15)
sns.set_style("darkgrid")
plt.bar(unemployement_rate, states)

plt.xlabel('Unemployment Rate(%)')
plt.ylabel('States')

plt.title("Unemployment rate State wise")
# Out:
# Text(0.5, 1.0, 'Unemployment rate State wise')

# %%
#Tripura is having highest Unemployement rate
